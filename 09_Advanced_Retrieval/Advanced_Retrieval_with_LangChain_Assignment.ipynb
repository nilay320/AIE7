# %% [markdown]
# # Advanced Retrieval with LangChain
#
# In the following notebook, we'll explore various methods of advanced retrieval using LangChain!
#
# We'll touch on:
#
# - Naive Retrieval
# - Best-Matching 25 (BM25)
# - Multi-Query Retrieval
# - Parent-Document Retrieval
# - Contextual Compression (a.k.a. Rerank)
# - Ensemble Retrieval
# - Semantic chunking
#
# We'll also discuss how these methods impact performance on our set of documents with a simple RAG chain.
#
# There will be two breakout rooms:
#
# - 🤝 Breakout Room Part #1
#   - Task 1: Getting Dependencies!
#   - Task 2: Data Collection and Preparation
#   - Task 3: Setting Up QDrant!
#   - Task 4-10: Retrieval Strategies
# - 🤝 Breakout Room Part #2
#   - Activity: Evaluate with Ragas

# %% [markdown]
# # 🤝 Breakout Room Part #1

# %% [markdown]
# ## Task 1: Getting Dependencies!
#
# We're going to need a few specific LangChain community packages, like OpenAI (for our [LLM](https://platform.openai.com/docs/models) and [Embedding Model](https://platform.openai.com/docs/guides/embeddings)) and Cohere (for our [Reranker](https://cohere.com/rerank)).

# %% [markdown]
# We'll also provide our OpenAI key, as well as our Cohere API key.

# %%
import os
import getpass

os.environ["OPENAI_API_KEY"] = getpass.getpass("Enter your OpenAI API Key:")

# %%
os.environ["COHERE_API_KEY"] = getpass.getpass("Cohere API Key:")

# %% [markdown]
# ## Task 2: Data Collection and Preparation
#
# We'll be using our Loan Data once again - this time the strutured data available through the CSV!

# %% [markdown]
# ### Data Preparation
#
# We want to make sure all our documents have the relevant metadata for the various retrieval strategies we're going to be applying today.

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader
from datetime import datetime, timedelta

loader = CSVLoader(
    file_path=f"./data/complaints.csv",
    metadata_columns=[
      "Date received", 
      "Product", 
      "Sub-product", 
      "Issue", 
      "Sub-issue", 
      "Consumer complaint narrative", 
      "Company public response", 
      "Company", 
      "State", 
      "ZIP code", 
      "Tags", 
      "Consumer consent provided?", 
      "Submitted via", 
      "Date sent to company", 
      "Company response to consumer", 
      "Timely response?", 
      "Consumer disputed?", 
      "Complaint ID"
    ]
)

loan_complaint_data = loader.load()

for doc in loan_complaint_data:
    doc.page_content = doc.metadata["Consumer complaint narrative"]

# %% [markdown]
# Let's look at an example document to see if everything worked as expected!

# %%
loan_complaint_data[0]
# Out:
# Document(metadata={'source': './data/complaints.csv', 'row': 0, 'Date received': '03/27/25', 'Product': 'Student loan', 'Sub-product': 'Federal student loan servicing', 'Issue': 'Dealing with your lender or servicer', 'Sub-issue': 'Trouble with how payments are being handled', 'Consumer complaint narrative': "The federal student loan COVID-19 forbearance program ended in XX/XX/XXXX. However, payments were not re-amortized on my federal student loans currently serviced by Nelnet until very recently. The new payment amount that is effective starting with the XX/XX/XXXX payment will nearly double my payment from {$180.00} per month to {$360.00} per month. I'm fortunate that my current financial position allows me to be able to handle the increased payment amount, but I am sure there are likely many borrowers who are not in the same position. The re-amortization should have occurred once the forbearance ended to reduce the impact to borrowers.", 'Company public response': 'None', 'Compan
# ...

# %% [markdown]
# ## Task 3: Setting up QDrant!
#
# Now that we have our documents, let's create a QDrant VectorStore with the collection name "LoanComplaints".
#
# We'll leverage OpenAI's [`text-embedding-3-small`](https://openai.com/blog/new-embedding-models-and-api-updates) because it's a very powerful (and low-cost) embedding model.
#
# > NOTE: We'll be creating additional vectorstores where necessary, but this pattern is still extremely useful.

# %%
from langchain_community.vectorstores import Qdrant
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

vectorstore = Qdrant.from_documents(
    loan_complaint_data,
    embeddings,
    location=":memory:",
    collection_name="LoanComplaints"
)

# %% [markdown]
# ## Task 4: Naive RAG Chain
#
# Since we're focusing on the "R" in RAG today - we'll create our Retriever first.

# %% [markdown]
# ### R - Retrieval
#
# This naive retriever will simply look at each review as a document, and use cosine-similarity to fetch the 10 most relevant documents.
#
# > NOTE: We're choosing `10` as our `k` here to provide enough documents for our reranking process later

# %%
naive_retriever = vectorstore.as_retriever(search_kwargs={"k" : 10})

# %% [markdown]
# ### A - Augmented
#
# We're going to go with a standard prompt for our simple RAG chain today! Nothing fancy here, we want this to mostly be about the Retrieval process.

# %%
from langchain_core.prompts import ChatPromptTemplate

RAG_TEMPLATE = """\
You are a helpful and kind assistant. Use the context provided below to answer the question.

If you do not know the answer, or are unsure, say you don't know.

Query:
{question}

Context:
{context}
"""

rag_prompt = ChatPromptTemplate.from_template(RAG_TEMPLATE)

# %% [markdown]
# ### G - Generation
#
# We're going to leverage `gpt-4.1-nano` as our LLM today, as - again - we want this to largely be about the Retrieval process.

# %%
from langchain_openai import ChatOpenAI

chat_model = ChatOpenAI(model="gpt-4.1-nano")

# %% [markdown]
# ### LCEL RAG Chain
#
# We're going to use LCEL to construct our chain.
#
# > NOTE: This chain will be exactly the same across the various examples with the exception of our Retriever!

# %%
from langchain_core.runnables import RunnablePassthrough
from operator import itemgetter
from langchain_core.output_parsers import StrOutputParser

naive_retrieval_chain = (
    # INVOKE CHAIN WITH: {"question" : "<<SOME USER QUESTION>>"}
    # "question" : populated by getting the value of the "question" key
    # "context"  : populated by getting the value of the "question" key and chaining it into the base_retriever
    {"context": itemgetter("question") | naive_retriever, "question": itemgetter("question")}
    # "context"  : is assigned to a RunnablePassthrough object (will not be called or considered in the next step)
    #              by getting the value of the "context" key from the previous step
    | RunnablePassthrough.assign(context=itemgetter("context"))
    # "response" : the "context" and "question" values are used to format our prompt object and then piped
    #              into the LLM and stored in a key called "response"
    # "context"  : populated by getting the value of the "context" key from the previous step
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's see how this simple chain does on a few different prompts.
#
# > NOTE: You might think that we've cherry picked prompts that showcase the individual skill of each of the retrieval strategies - you'd be correct!

# %%
naive_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'Based on the provided context, the most common issues with loans appear to involve errors and misconduct by loan servicers, such as:\n\n- Receiving bad or incorrect information about the loan\n- Errors in loan balances and misapplied payments\n- Unauthorized or unnotified transfers of loans between servicers\n- Trouble with payment application, including inability to direct payments toward principal\n- Discrepancies and incorrect reporting of account status and delinquency\n- Unfair or wrongful increases in interest rates and balances\n- Mishandling of loan data and privacy violations\n- Difficulties accessing accurate loan information and documentation\n\nThese complaints suggest that a prevalent issue is poor management and communication by loan servicers, leading to inaccurate information, financial hardship, and lack of transparency for borrowers.'

# %%
naive_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided information, yes, some complaints were not handled in a timely manner. Specifically, the complaint with Complaint ID 12709087 received on 03/28/25 from MOHELA was marked as "No" in response to whether the response was timely. Additionally, the complaint with Complaint ID 12975634 received on 04/14/25 from Maximus Federal Services, Inc. was marked as "Yes," indicating it was handled timely. \n\nTherefore, at least one complaint (ID 12709087) did not get handled within the expected timeframe.'

# %%
naive_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People failed to pay back their loans primarily due to a combination of factors including:\n\n1. Lack of clear communication and notification from loan servicers about important loan details, such as when repayment is supposed to resume or when loans are transferred to new servicers.\n2. Difficulty understanding or managing complex interest accumulation, particularly when loans are in forbearance or deferment, leading to interest continuing to accrue and increasing the total debt.\n3. Limited options or options that extend the repayment period, making it financially challenging to keep up with payments without sacrificing basic living expenses.\n4. Misinformation or lack of transparency by lenders and servicers about repayment terms, interest rates, and loan transfer processes, which can trap borrowers in unmanageable debt.\n5. Financial hardships, including stagnant wages, economic downturns, or personal circumstances like unemployment or illness, which make consistent repayment di
# ...

# %% [markdown]
# Overall, this is not bad! Let's see if we can make it better!

# %% [markdown]
# ## Task 5: Best-Matching 25 (BM25) Retriever
#
# Taking a step back in time - [BM25](https://www.nowpublishers.com/article/Details/INR-019) is based on [Bag-Of-Words](https://en.wikipedia.org/wiki/Bag-of-words_model) which is a sparse representation of text.
#
# In essence, it's a way to compare how similar two pieces of text are based on the words they both contain.
#
# This retriever is very straightforward to set-up! Let's see it happen down below!

# %%
from langchain_community.retrievers import BM25Retriever

bm25_retriever = BM25Retriever.from_documents(loan_complaint_data, )

# %% [markdown]
# We'll construct the same chain - only changing the retriever.

# %%
bm25_retrieval_chain = (
    {"context": itemgetter("question") | bm25_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's look at the responses!

# %%
bm25_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'Based on the provided context, the most common issue with loans appears to be problems related to dealing with lenders or servicers, such as miscommunication, incorrect information, or issues with how payments are being handled. Specifically, complaints frequently involve difficulties in applying payments correctly, disputes over loan balances or interest calculations, and problems with loan information accuracy.'

# %%
bm25_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided context, it appears that most complaints were responded to with a "Closed with explanation" status and were marked as "Timely response? Yes." This suggests that the complaints did not experience delays in handling. However, there are repeated issues mentioned in some complaints, such as failed attempts to get corrections or responses over prolonged periods (e.g., long wait times, missed calls), but the responses provided by the companies indicated timely handling overall. \n\nTherefore, I do not have evidence from the context that any complaints were not handled in a timely manner.'

# %%
bm25_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# "People fail to pay back their loans for various reasons, including issues with payment plans, miscommunication or lack of communication from lenders or servicers, challenges in accessing or receiving proper assistance or information, and complications arising from loan transfers or administrative errors. For example, some borrowers experienced problems with their payment plans or forbearance, leading to missed payments and billing disputes. Others were unaware of loan transfers or automatic payment discontinuations, which caused them to fall behind or have their credit negatively impacted. Overall, these issues often stem from inadequate communication, improper handling by loan servicers, or administrative complications beyond the borrower's control."

# %% [markdown]
# It's not clear that this is better or worse, if only we had a way to test this (SPOILERS: We do, the second half of the notebook will cover this)

# %% [markdown]
# #### ❓ Question #1:
#
# Give an example query where BM25 is better than embeddings and justify your answer.

# %% [markdown]
# ##### ✅ Answer:
#
# **Example Query:** "Does FAFSA provide student loans?"
#
# **Justification:** BM25 excels at exact keyword matching and is particularly effective for:
#
# -   **Acronym searches** (like "FAFSA") where exact term matching is crucial
# -   **Company name or ticker searches** where specific terminology matters
# -   **Factual queries** requiring precise keyword matching rather than semantic understanding
# -   **Boolean-style searches** where the presence/absence of specific terms is more important than semantic similarity
#
# BM25 uses sparse vector representation based on Bag-of-Words, making it superior for queries where exact term frequency and presence matter more than contextual meaning.

# %% [markdown]
# ## Task 6: Contextual Compression (Using Reranking)
#
# Contextual Compression is a fairly straightforward idea: We want to "compress" our retrieved context into just the most useful bits.
#
# There are a few ways we can achieve this - but we're going to look at a specific example called reranking.
#
# The basic idea here is this:
#
# - We retrieve lots of documents that are very likely related to our query vector
# - We "compress" those documents into a smaller set of *more* related documents using a reranking algorithm.
#
# We'll be leveraging Cohere's Rerank model for our reranker today!
#
# All we need to do is the following:
#
# - Create a basic retriever
# - Create a compressor (reranker, in this case)
#
# That's it!
#
# Let's see it in the code below!

# %%
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank

compressor = CohereRerank(model="rerank-v3.5")
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=naive_retriever
)

# %% [markdown]
# Let's create our chain again, and see how this does!

# %%
contextual_compression_retrieval_chain = (
    {"context": itemgetter("question") | compression_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %%
contextual_compression_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# "Based on the provided information, the most common issues with loans, particularly student loans in this context, involve errors and misconduct by loan servicers. These include errors in loan balances, misapplied payments, wrongful denials of payment plans, inadequate communication, lack of proper documentation, unethical and unauthorized transfers of loans, mishandling of personal information, and violations of legal privacy and reporting regulations. \n\nIn summary, a frequent issue is dealing with errors, mismanagement, and misconduct by loan servicers, leading to confusion, incorrect account information, and violations of borrowers' rights."

# %%
contextual_compression_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided complaints, it appears that at least one complaint was handled in a timely manner, as indicated by the response status "Closed with explanation" and "Timely response? Yes" for the complaint against Maximus Federal Services, Inc. \n\nHowever, there are multiple complaints mentioning significant delays, such as the complaint regarding ongoing unresolved issues for over a year and nearly 18 months without resolution, and another complaint about a problem that has persisted over 2-3 weeks. These suggest that some complaints were not handled in a timely manner.\n\nIn summary, while some complaints were addressed promptly, others, including some that have been pending for over a year or longer, were not handled in a timely manner.'

# %%
contextual_compression_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People failed to pay back their loans for several reasons, including:\n\n1. **Lack of Awareness and Poor Communication:** Some borrowers were not informed about their obligation to repay student loans, especially when loan transfers occurred without their knowledge or consent. For example, one borrower stated they were unaware they had to repay the loan until a certain time and did not receive proper notification when their loan was transferred to another servicer.\n\n2. **Incorrect or Confusing Information:** Borrowers received inconsistent or incorrect information about their loan balances, interest, or payment requirements. This confusion made it difficult to understand their outstanding debt and when or how to make payments.\n\n3. **Accumulating Interest and Difficult Payment Options:** Many borrowers experienced interest continue to grow despite making payments or entered into forbearance or deferment. These options sometimes caused interest to accrue, increasing the total amou
# ...

# %% [markdown]
# We'll need to rely on something like Ragas to help us get a better sense of how this is performing overall - but it "feels" better!

# %% [markdown]
# ## Task 7: Multi-Query Retriever
#
# Typically in RAG we have a single query - the one provided by the user.
#
# What if we had....more than one query!
#
# In essence, a Multi-Query Retriever works by:
#
# 1. Taking the original user query and creating `n` number of new user queries using an LLM.
# 2. Retrieving documents for each query.
# 3. Using all unique retrieved documents as context
#
# So, how is it to set-up? Not bad! Let's see it down below!

# %%
from langchain.retrievers.multi_query import MultiQueryRetriever

multi_query_retriever = MultiQueryRetriever.from_llm(
    retriever=naive_retriever, llm=chat_model
)

# %%
multi_query_retrieval_chain = (
    {"context": itemgetter("question") | multi_query_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %%
multi_query_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'The most common issue with loans, based on the provided complaints, appears to be problems related to "Dealing with your lender or servicer." Specifically, many complaints highlight issues such as errors in loan balances, misapplied payments, wrongful denials of repayment plans, lack of proper communication, inaccurate reporting (including default and delinquency statuses), and difficulty in obtaining accurate information or corrections. Additionally, complaints frequently mention errors in loan information, unauthorized account activity, and mishandling of loan statuses, which collectively point towards servicing problems as the most prevalent issue.'

# %%
multi_query_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# "Based on the provided complaints, several complaints indicate that issues were not handled in a timely manner. For example:\n\n- Complaint ID 12709087 against MOHELA: The user reports that despite being told their application would be processed in 5-7 business days, it has been over two to three weeks with no resolution.\n- Complaint ID 12973003 against EdFinancial Services: The user states it has been nearly 18 months with no resolution despite multiple follow-ups, indicating significant delay.\n- Complaint ID 12857752 against Nelnet: The user reports that a dispute was submitted over 30 days ago and they still haven't received a response.\n- Complaint ID 12739706 against MOHELA: The user states they have been waiting over 3 hours on the phone multiple times with no response and are still waiting for resolution.\n\nAdditionally, some complaints mention delays longer than the standard response times or failure to respond at all, which suggests that some complaints did not get handle
# ...

# %%
multi_query_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People failed to pay back their loans for several reasons, including:\n\n1. Mismanagement and Errors: Servicers, such as Maximus Federal Services and MOHELA, sometimes made errors in loan balances, misapplied payments, or provided bad information about loans, leading to delinquencies and misunderstandings.\n\n2. Lack of Proper Notice and Communication: Borrowers often reported not receiving timely or adequate notices about repayment start dates, delinquency status, or important updates, which prevented them from managing their payments effectively.\n\n3. Financial Hardship: Many borrowers experienced significant financial difficulties, hardships, or changes in circumstances (e.g., unemployment, medical issues, homelessness) that made repayment difficult or impossible.\n\n4. Servicing Practices and Coercion: In some cases, borrowers were steered into long-term forbearances or coercive consolidation practices without being properly informed of their repayment options like income-drive
# ...

# %% [markdown]
# #### ❓ Question #2:
#
# Explain how generating multiple reformulations of a user query can improve recall.

# %% [markdown]
# ##### ✅ Answer:
#
# **Multi-query retrieval improves recall by:**
#
# 1.  **Addressing Query Ambiguity**: Different phrasings can capture various aspects of the user's intent
# 2.  **Expanding Beyond Single Vector Limitations**: While embeddings handle synonyms, multiple reformulations create different embedding vectors that can capture various semantic angles of the same information need
# 3.  **Reducing Single-Point Failure**: If one query formulation fails to find relevant docs, others might succeed
# 4.  **Multiple Semantic Perspectives**: Different query formulations emphasize different aspects of the same information need, creating distinct embedding vectors that can retrieve semantically relevant documents missed by the original single embedding vector
# 5.  **Improving Retrieval Diversity**: Each reformulated query can surface different relevant documents, creating a more comprehensive result set
#
# The process works by:
#
# -   Using an LLM to generate multiple query variations
# -   Retrieving documents for each variation
# -   Combining and deduplicating the results
# -   Providing a richer context to the generation model

# %% [markdown]
# ## Task 8: Parent Document Retriever
#
# A "small-to-big" strategy - the Parent Document Retriever works based on a simple strategy:
#
# 1. Each un-split "document" will be designated as a "parent document" (You could use larger chunks of document as well, but our data format allows us to consider the overall document as the parent chunk)
# 2. Store those "parent documents" in a memory store (not a VectorStore)
# 3. We will chunk each of those documents into smaller documents, and associate them with their respective parents, and store those in a VectorStore. We'll call those "child chunks".
# 4. When we query our Retriever, we will do a similarity search comparing our query vector to the "child chunks".
# 5. Instead of returning the "child chunks", we'll return their associated "parent chunks".
#
# Okay, maybe that was a few steps - but the basic idea is this:
#
# - Search for small documents
# - Return big documents
#
# The intuition is that we're likely to find the most relevant information by limiting the amount of semantic information that is encoded in each embedding vector - but we're likely to miss relevant surrounding context if we only use that information.
#
# Let's start by creating our "parent documents" and defining a `RecursiveCharacterTextSplitter`.

# %%
from langchain.retrievers import ParentDocumentRetriever
from langchain.storage import InMemoryStore
from langchain_text_splitters import RecursiveCharacterTextSplitter
from qdrant_client import QdrantClient, models

parent_docs = loan_complaint_data
child_splitter = RecursiveCharacterTextSplitter(chunk_size=750)

# %% [markdown]
# We'll need to set up a new QDrant vectorstore - and we'll use another useful pattern to do so!
#
# > NOTE: We are manually defining our embedding dimension, you'll need to change this if you're using a different embedding model.

# %%
from langchain_qdrant import QdrantVectorStore

client = QdrantClient(location=":memory:")

client.create_collection(
    collection_name="full_documents",
    vectors_config=models.VectorParams(size=1536, distance=models.Distance.COSINE)
)

parent_document_vectorstore = QdrantVectorStore(
    collection_name="full_documents", embedding=OpenAIEmbeddings(model="text-embedding-3-small"), client=client
)

# %% [markdown]
# Now we can create our `InMemoryStore` that will hold our "parent documents" - and build our retriever!

# %%
store = InMemoryStore()

parent_document_retriever = ParentDocumentRetriever(
    vectorstore = parent_document_vectorstore,
    docstore=store,
    child_splitter=child_splitter,
)

# %% [markdown]
# By default, this is empty as we haven't added any documents - let's add some now!

# %%
parent_document_retriever.add_documents(parent_docs, ids=None)

# %% [markdown]
# We'll create the same chain we did before - but substitute our new `parent_document_retriever`.

# %%
parent_document_retrieval_chain = (
    {"context": itemgetter("question") | parent_document_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's give it a whirl!

# %%
parent_document_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# 'The most common issue with loans, based on the provided complaints, appears to be related to errors and misconduct in federal student loan servicing. This includes problems such as incorrect or inconsistent reporting of loan information, errors in loan balances, misapplied payments, wrongful denials of payment plans, and issues arising from poor communication or system complexities that lead to confusion and systemic breakdowns.'

# %%
parent_document_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided information, yes, there are complaints indicating they were not handled in a timely manner. For example, complaints involving Mohela (rows 441 and 84) show responses labeled as "No" for timely response, and the consumer reports have not heard back despite multiple follow-ups over extended periods. Additionally, one complaint about credit bureau disputes (row 474) was responded to within the required time frame, but the consumer still experienced a delay in receiving a response, which they consider negligent.\n\nTherefore, the answer is: Yes, some complaints were not handled in a timely manner.'

# %%
parent_document_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People failed to pay back their loans primarily due to factors such as mismanagement by loan servicers, lack of clear communication about payment start dates, failure to provide proper notification or education regarding repayment obligations, and severe financial hardships resulting from the long-term consequences of their educational investments. In some cases, issues like institutional misrepresentation, inability to find employment after graduation, or complications related to loan ownership and verification also contributed to their inability to repay loans.'

# %% [markdown]
# Overall, the performance *seems* largely the same. We can leverage a tool like [Ragas]() to more effectively answer the question about the performance.

# %% [markdown]
# ## Task 9: Ensemble Retriever
#
# In brief, an Ensemble Retriever simply takes 2, or more, retrievers and combines their retrieved documents based on a rank-fusion algorithm.
#
# In this case - we're using the [Reciprocal Rank Fusion](https://plg.uwaterloo.ca/~gvcormac/cormacksigir09-rrf.pdf) algorithm.
#
# Setting it up is as easy as providing a list of our desired retrievers - and the weights for each retriever.

# %%
from langchain.retrievers import EnsembleRetriever

retriever_list = [bm25_retriever, naive_retriever, parent_document_retriever, compression_retriever, multi_query_retriever]
equal_weighting = [1/len(retriever_list)] * len(retriever_list)

ensemble_retriever = EnsembleRetriever(
    retrievers=retriever_list, weights=equal_weighting
)

# %% [markdown]
# We'll pack *all* of these retrievers together in an ensemble.

# %%
ensemble_retrieval_chain = (
    {"context": itemgetter("question") | ensemble_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# Let's look at our results!

# %%
ensemble_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# "Based on the data provided, the most common issue with loans appears to be problems related to dealing with lenders or servicers, including sub-issues such as receiving bad information about the loan, trouble with how payments are being handled, or issues with loan transfer and account management. Many complaints highlight mishandling of loan information, unauthorized transfers, inaccuracies, and lack of clear communication, which significantly impact borrowers' financial and credit situations."

# %%
ensemble_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided complaints, yes, some complaints indicate that complaints were not handled in a timely manner. For example, one complaint against MOHELA (Complaint ID: 12739706) explicitly states "Timely response?": "No." Additionally, multiple complaints mention delays, poor responses, or lack of follow-up, suggesting that certain complaints were not addressed promptly.'

# %%
ensemble_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# 'People failed to pay back their loans primarily due to a combination of factors highlighted in the complaints:\n\n1. **Lack of Clear Communication and Notifications:**\n   - Many borrowers were not properly informed about when their repayment would resume after forbearance or deferment periods.\n   - Servicers often did not notify borrowers of changes in account status, loan transfer, or upcoming payments, leading to unintentional delinquency.\n\n2. **Loan Servicer Practices and Errors:**\n   - Servicers frequently reversed or failed to process payments correctly, with multiple complaints of unauthorized payment reversals, misapplied funds, or missed payments that appeared as delinquent.\n   - Some borrowers were placed into forbearance or other repayment plans without clear understanding of the implications, especially interest accumulation.\n\n3. **Interest Accumulation and Loan Management Issues:**\n   - Forbearance, deferment, or management practices often resulted in interest a
# ...

# %% [markdown]
# ## Task 10: Semantic Chunking
#
# While this is not a retrieval method - it *is* an effective way of increasing retrieval performance on corpora that have clean semantic breaks in them.
#
# Essentially, Semantic Chunking is implemented by:
#
# 1. Embedding all sentences in the corpus.
# 2. Combining or splitting sequences of sentences based on their semantic similarity based on a number of [possible thresholding methods](https://python.langchain.com/docs/how_to/semantic-chunker/):
#   - `percentile`
#   - `standard_deviation`
#   - `interquartile`
#   - `gradient`
# 3. Each sequence of related sentences is kept as a document!
#
# Let's see how to implement this!

# %% [markdown]
# We'll use the `percentile` thresholding method for this example which will:
#
# Calculate all distances between sentences, and then break apart sequences of setences that exceed a given percentile among all distances.

# %%
from langchain_experimental.text_splitter import SemanticChunker

semantic_chunker = SemanticChunker(
    embeddings,
    breakpoint_threshold_type="percentile"
)

# %% [markdown]
# Now we can split our documents.

# %%
semantic_documents = semantic_chunker.split_documents(loan_complaint_data[:20])

# %% [markdown]
# Let's create a new vector store.

# %%
semantic_vectorstore = Qdrant.from_documents(
    semantic_documents,
    embeddings,
    location=":memory:",
    collection_name="Loan_Complaint_Data_Semantic_Chunks"
)

# %% [markdown]
# We'll use naive retrieval for this example.

# %%
semantic_retriever = semantic_vectorstore.as_retriever(search_kwargs={"k" : 10})

# %% [markdown]
# Finally we can create our classic chain!

# %%
semantic_retrieval_chain = (
    {"context": itemgetter("question") | semantic_retriever, "question": itemgetter("question")}
    | RunnablePassthrough.assign(context=itemgetter("context"))
    | {"response": rag_prompt | chat_model, "context": itemgetter("context")}
)

# %% [markdown]
# And view the results!

# %%
semantic_retrieval_chain.invoke({"question" : "What is the most common issue with loans?"})["response"].content
# Out:
# "Based on the provided complaints data, the most common issue with loans appears to be problems related to servicing and administration, such as:\n\n- Struggling to repay or issues with repayment plans and recalculations\n- Poor communication and lack of transparency from loan servicers\n- Errors or incorrect information on credit reports and account status\n- Difficulties with payment processing, auto-debit setup, or account verification\n- Problems with loan forgiveness, discharge, or discharge disputes\n- Unauthorized or improper reporting and data breaches\n\nWhile individual complaints vary, a recurring theme is dissatisfaction with loan servicers' handling of repayment, communication issues, and errors in loan account information. If you're looking for the most general or common issue, it tends to revolve around servicing problems—especially mismanagement, miscommunication, or errors in the administration of student loans.\n\nPlease note, I do not have data on all types of loan
# ...

# %%
semantic_retrieval_chain.invoke({"question" : "Did any complaints not get handled in a timely manner?"})["response"].content
# Out:
# 'Based on the provided complaints, it appears that several complaints did not get handled in a timely manner. Specifically, in at least one case involving Nelnet (Complaint ID: 13331376), the company\'s response was marked as "Closed with explanation," which often indicates that the complaint was not resolved to the consumer\'s satisfaction or was not addressed promptly. Also, the notable repeated issues about the company’s failure to respond or correct errors suggest delays or lack of timely handling.\n\nFurthermore, multiple complaints mention ongoing issues such as billing errors, lack of communication, or attempts at dispute that remain unresolved or improperly handled. The consistent pattern of "Closed with explanation" responses and unresolved issues imply that some complaints were not addressed in a timely manner.\n\nIf you need a specific confirmation about a particular complaint, please let me know!'

# %%
semantic_retrieval_chain.invoke({"question" : "Why did people fail to pay back their loans?"})["response"].content
# Out:
# "Based on the provided context, people failed to pay back their loans for various reasons, including issues with loan servicing, miscommunication, and alleged misconduct by servicers. Specific reasons mentioned include receiving bad or unclear information about their loans, difficulty with payment processing or log-in issues, and alleged deliberate stalling or unreasonable requests from loan servicers that discourage borrowers from continuing payments. Additionally, some borrowers experienced problems such as their loans being reported incorrectly or in default despite never having been in default, which impacted their ability to repay. Overall, systemic issues, lack of transparency, and alleged unfair or illegal practices by loan administrators contributed to borrowers' failure to successfully repay their loans."

# %% [markdown]
# #### ❓ Question #3:
#
# If sentences are short and highly repetitive (e.g., FAQs), how might semantic chunking behave, and how would you adjust the algorithm?

# %% [markdown]
# ##### ✅ **Answer:**
#
# **Behavior Issues:**
#
# -   **Over-chunking**: Similar FAQ patterns ("How do I...", "What is...") would create overly large chunks mixing unrelated topics
# -   **Loss of precision**: Structural similarity would override semantic content differences
#
# **Algorithm Adjustments:**
#
# 1.  **Hybrid approach**: Combine semantic chunking with rule-based FAQ structure preservation (Q:A pairs)
# 2.  **Stricter thresholds**: Use lower percentiles or gradient-based thresholding for finer granularity
# 3.  **Content weighting**: Emphasize key nouns/entities over structural question words in embeddings
# 4.  **Topic pre-categorization**: Group FAQs by domain before applying semantic chunking
#
# This maintains FAQ coherence while preventing unrelated topics from being grouped together based on similar question structures.

# %% [markdown]
# # 🤝 Breakout Room Part #2

# %% [markdown]
# #### 🏗️ Activity #1
#
# Your task is to evaluate the various Retriever methods against eachother.
#
# You are expected to:
#
# 1. Create a "golden dataset"
#  - Use Synthetic Data Generation (powered by Ragas, or otherwise) to create this datasete
# 2. Evaluate each retriever with *retriever specific* Ragas metrics
#  - Semantic Chunking is not considered a retriever method and will not be required for marks, but you may find it useful to do a "semantic chunking on" vs. "semantic chunking off" comparision between them
# 3. Compile these in a list and write a small paragraph about which is best for this particular data and why.
#
# Your analysis should factor in:
#   - Cost
#   - Latency
#   - Performance
#
# > NOTE: This is **NOT** required to be completed in class. Please spend time in your breakout rooms creating a plan before moving on to writing code.

# %% [markdown]
# ##### HINTS:
#
# - LangSmith provides detailed information about latency and cost.

# %% [markdown]
# ##### ✅ Answer:
# 1.

# %%
from ragas.llms import LangchainLLMWrapper
from ragas.embeddings import LangchainEmbeddingsWrapper
from langchain_openai import ChatOpenAI
from langchain_openai import OpenAIEmbeddings
from ragas.testset.synthesizers import SingleHopSpecificQuerySynthesizer, MultiHopAbstractQuerySynthesizer, MultiHopSpecificQuerySynthesizer
from ragas import EvaluationDataset, evaluate

# import random

generator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-nano"))
generator_embeddings = LangchainEmbeddingsWrapper(OpenAIEmbeddings())

query_distribution = [
        (SingleHopSpecificQuerySynthesizer(llm=generator_llm), 0.5),
        (MultiHopAbstractQuerySynthesizer(llm=generator_llm), 0.25),
        (MultiHopSpecificQuerySynthesizer(llm=generator_llm), 0.25),
]


from ragas.testset import TestsetGenerator

# loan_complaint_subset = random.sample(loan_complaint_data, 50)

generator = TestsetGenerator(llm=generator_llm, embedding_model=generator_embeddings)
#dataset = generator.generate_with_langchain_docs(loan_complaint_subset, testset_size=10, query_distribution=query_distribution)
test_dataset = generator.generate_with_langchain_docs(loan_complaint_data[:20], testset_size=10, query_distribution=query_distribution)
# Out:
# ...
# Applying CustomNodeFilter:   0%|          | 0/20 [00:00<?, ?it/s]
# Node c274515e-db18-4ab9-a1a1-8a409e10374d does not have a summary. Skipping filtering.
# Node 29332610-0388-435c-897c-fcffafda8493 does not have a summary. Skipping filtering.
# Node 993f8723-62d4-4953-a79e-bb96022415b7 does not have a summary. Skipping filtering.
# Node 4df2f837-fc18-4dd0-9d1b-32a89353798e does not have a summary. Skipping filtering.
# Node 924de7a7-3adb-460c-93d6-c142d655178d does not have a summary. Skipping filtering.
# Node 0c92a611-6c36-4c0d-8b55-e04519457dd7 does not have a summary. Skipping filtering.
# Applying [EmbeddingExtractor, ThemesExtractor, NERExtractor]:   0%|          | 0/51 [00:00<?, ?it/s]
# Applying [CosineSimilarityBuilder, OverlapScoreBuilder]:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
# Generating Samples:   0%|          | 0/11 [00:00<?, ?it/s]

# %%
test_dataset.to_pandas()
# Out:
#                                            user_input  \
# 0   Can you explain the status of re-amortization ...
# 1   How does Aidvantage handle IDR recertification...
# 2   How does FERPA relate to the violation of my p...
# 3   What are the implications of being in forbeara...
# 4   What does 15 U.S.C. 1681i require credit repor...
# 5   How do the violations of law and misconduct by...
# 6   How do the legal protections for student recor...
# 7   Did Nelnet fail to respond to certified mail a...
# 8   How does the violation of the Higher Education...
# 9   How NelNet handle the payment issues after acc...
# 10  Nelnet not re-amortize loans after forbearance...
#
#                                    reference_contexts  \
# 0   [The federal student loan COVID-19 forbearance...
# 1   [I submitted my annual Income-Driven Repayment...
# 2   [My personal and financial data was compromise...
# 3   [Since the resumption of federal loan payments...
# ...

# %% [markdown]
# 2.

# %%
from uuid import uuid4
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = getpass.getpass("Enter your Langchain API Key:")
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"] = f"AIM - StudentLoanRetrievalEval - {uuid4().hex[0:8]}"
from langchain.callbacks.tracers import LangChainTracer
from langchain.schema.runnable import RunnableConfig

# %%
import copy
from ragas.metrics import LLMContextRecall,ContextEntityRecall,LLMContextPrecisionWithReference,NonLLMContextPrecisionWithReference
from ragas import RunConfig



custom_run_config = RunConfig(timeout=360)


retrievers = {
    "Naive": naive_retriever,
    "BM25": bm25_retriever,
    "ContextualCompression": compression_retriever,
    "MultiQuery": multi_query_retriever,
    "ParentDocument": parent_document_retriever,
    "Ensemble": ensemble_retriever
}

evaluator_llm = LangchainLLMWrapper(ChatOpenAI(model="gpt-4.1-mini"))

retriever_results = {}

#tracer = LangChainTracer(project_name=f"{os.environ["LANGCHAIN_PROJECT"]} - {retriever_name}")


for retriever_name, retriever in retrievers.items():
    print(f"Evaluating {retriever_name}...")

#Lets make a deep copy of test dataset
    test_dataset_copy = copy.deepcopy(test_dataset)

    for test_row in test_dataset_copy:
        docs = retriever.invoke(test_row.eval_sample.user_input)
        test_row.eval_sample.retrieved_contexts = [doc.page_content for doc in docs]
  #       contexts.append(context)
 # 
    evaluation_dataset = EvaluationDataset.from_pandas(test_dataset_copy.to_pandas())
    
    tracer = LangChainTracer(project_name=f"{os.environ["LANGCHAIN_PROJECT"]} - {retriever_name}")

    # Evaluate THIS retriever
    result = evaluate(
        dataset=evaluation_dataset,
        metrics=[LLMContextRecall(),ContextEntityRecall(),LLMContextPrecisionWithReference(),NonLLMContextPrecisionWithReference()],
        llm=evaluator_llm,
        run_config=custom_run_config,
        callbacks=[tracer]
    )
    
    retriever_results[retriever_name] = result

print(retriever_results)
# Out:
# Evaluating Naive...
# Evaluating:   0%|          | 0/44 [00:00<?, ?it/s]
# Evaluating BM25...
# Evaluating:   0%|          | 0/44 [00:00<?, ?it/s]
# Evaluating ContextualCompression...
# Evaluating:   0%|          | 0/44 [00:00<?, ?it/s]
# Evaluating MultiQuery...
# Evaluating:   0%|          | 0/44 [00:00<?, ?it/s]
# Evaluating ParentDocument...
# Evaluating:   0%|          | 0/44 [00:00<?, ?it/s]
# Evaluating Ensemble...
# Evaluating:   0%|          | 0/44 [00:00<?, ?it/s]
# Exception raised in Job[13]: TimeoutError()
# ...

# %% [markdown]
# 3.

# %% [markdown]
# RAG Retriever Evaluation Analysis
# ==================================
#
# Raw Data Summary
# ----------------
#
# | Retriever | Context Recall | Entity Recall | LLM Precision | Non-LLM Precision | Overall Score |
# | --- | --- | --- | --- | --- | --- |
# | **Contextual Compression** | 0.9545 | 0.4905 | **0.9091** | 0.6515 | **0.8566** |
# | **Multi-Query** | **1.0000** | 0.4791 | 0.8284 | **0.6863** | 0.8246 |
# | **Naive** | **1.0000** | 0.4545 | 0.8261 | 0.6494 | 0.8136 |
# | **Ensemble** | **1.0000** | 0.4582 | 0.7953 | 0.6831 | 0.8083 |
# | **Parent Document** | 0.7955 | 0.3865 | 0.8182 | 0.4394 | 0.7201 |
# | **BM25** | 0.6030 | 0.3261 | 0.7348 | 0.5000 | 0.5962 |
#
# **Overall Score Formula:**
#
# ```
# Overall Score = (Context_Recall × 0.35) + (Entity_Recall × 0.20) + (LLM_Precision × 0.35) + (NonLLM_Precision × 0.10)
# ```
#
# **Rationale for Weights:**
#
# -   **Context Recall (35%)**: High weight because finding relevant information is critical
# -   **LLM Precision (35%)**: High weight to avoid noise and irrelevant context
# -   **Entity Recall (20%)**: Higher weight for domain-specific entity recognition (companies, loan types, regulatory terms)
# -   **Non-LLM Precision (10%)**: Lower weight as it's a simpler, less sophisticated precision metric
#
#
# Cost-Performance Analysis
# -------------------------
#
# ### Cost per Query (10 test queries)
#
# | Retriever | Cost per Query | Tokens per Query | Time per Query |
# | --- | --- | --- | --- |
# | **Contextual Compression** | $0.004 | 10,026 | 0.90s |
# | **Parent Document** | $0.005 | 12,600 | 2.55s |
# | **BM25** | $0.006 | 14,147 | 1.51s |
# | **Naive** | $0.007 | 24,486 | 2.47s |
# | **Multi-Query** | $0.015 | 35,504 | 3.94s |
# | **Ensemble** | $0.018 | 47,776 | 36.01s |
#
# ### Value Score (Performance ÷ Cost)
#
# | Rank | Retriever | Value Score | Rationale |
# | --- | --- | --- | --- |
# | **1** | **Contextual Compression** | **213.4** | Best performance at lowest cost |
# | **2** | **Parent Document** | **142.5** | Moderate performance, low cost |
# | **3** | **Naive** | **116.3** | Good performance, moderate cost |
# | **4** | **BM25** | **98.5** | Poor performance but very low cost |
# | **5** | **Multi-Query** | **54.9** | Good performance but high cost |
# | **6** | **Ensemble** | **45.0** | Good performance but highest cost |
#
# Contextual Compression emerged as the optimal retriever for student loan complaints, achieving the highest performance score (0.8566) using weighted Ragas metrics (Context Recall 35%, LLM Precision 35%, Entity Recall 20%, Non-LLM Precision 10%). Despite being the fastest (8.99s) and cheapest ($0.004/query), it outperformed all alternatives including the expensive Ensemble retriever. Surprisingly, BM25 significantly underperformed (0.5962) in this keyword-rich domain, demonstrating that semantic understanding and precision filtering outweigh term frequency matching for complex complaint narratives. Contextual Compression's reranking approach effectively filters noise while preserving regulatory information, making it the clear production choice.
